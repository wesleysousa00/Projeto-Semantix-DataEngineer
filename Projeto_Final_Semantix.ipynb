# %% [markdown]
# # Projeto Final Curso Data Engineer - Semantix

# %% [markdown]
# ### Aluno: Wesley Sousa

# %% [markdown]
# - O objetivo deste projeto é desmontrar as habilidades adquiridas neste curso, realizando um projeto prático utilizando diferentes ferramentas de Big Data

# %%
# Importações

from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql import functions as f

# %% [markdown]
# ## 1. Enviar os dados para o hdfs
#
# - Dados: https://mobileapps.saude.gov.br/esus-vepi/files/unAFkcaNDeXajurGB7LChj8SgQYS2ptm/04bd3419b22b9cc5c6efac2c6528100d_HIST_PAINEL_COVIDBR_06jul2021.rar

# %%
# Primeiro passo é criar um diretório chamado covid no hdfs

# !hdfs dfs -mkdir /user/wesley/covid

# %%
# Verificando se o diretório foi criado

# !hdfs dfs -ls /user/wesley/
# Out:
# Found 8 items
# drwxr-xr-x   - root supergroup          0 2022-08-06 01:40 /user/wesley/covid
# drwxr-xr-x   - root supergroup          0 2022-08-01 13:38 /user/wesley/data
# drwxr-xr-x   - root supergroup          0 2022-07-29 11:12 /user/wesley/names_us_parquet
# drwxr-xr-x   - root supergroup          0 2022-08-02 11:56 /user/wesley/projeto_python
# drwxr-xr-x   - root supergroup          0 2022-08-01 14:31 /user/wesley/relatorio_anual
# drwxr-xr-x   - root supergroup          0 2022-08-03 11:50 /user/wesley/stream
# drwxr-xr-x   - root supergroup          0 2022-08-01 13:38 /user/wesley/teste_csv
# drwxr-xr-x   - root supergroup          0 2022-08-06 19:48 /user/wesley/visual2

# %% [markdown]
# - Baixei o arquivo no Linux na seguinte pasta docker-bigdata/input/exercises-data
# - sudo curl -O https://mobileapps.saude.gov.br/esus-vepi/files/unAFkcaNDeXajurGB7LChj8SgQYS2ptm/04bd3419b22b9cc5c6efac2c6528100d_HIST_PAINEL_COVIDBR_06jul2021.rar
# - Após baixar o arquivo, foi necessário baixar um descompactador, para isto utilizei os comandos abaixo.
# - sudo apt-get install rar unrar
# - e o comando para descompactar o arquivo
# - sudo unrar x 04bd3419b22b9cc5c6efac2c6528100d_HIST_PAINEL_COVIDBR_06jul2021.rar

# %% [markdown]
# - Para enviar o arquivo para o hdfs, precisamos acessar o container do namenode utilizando o comando
# - docker exec -it namenode bash ou docker exec -it namenode /bin/bash
# - Depois de acessar, precisamos enviar os arquivos utilizando os comandos abaixo
# - root@namenode:/# hdfs dfs -put /input/exercises-data/HIST_PAINEL_COVIDBR_2020_Parte1_06jul2021.csv /user/wesley/covid
# - root@namenode:/# hdfs dfs -put /input/exercises-data/HIST_PAINEL_COVIDBR_2020_Parte2_06jul2021.csv /user/wesley/covid
# - root@namenode:/# hdfs dfs -put /input/exercises-data/HIST_PAINEL_COVIDBR_2021_Parte1_06jul2021.csv /user/wesley/covid
# - root@namenode:/# hdfs dfs -put /input/exercises-data/HIST_PAINEL_COVIDBR_2021_Parte2_06jul2021.csv /user/wesley/covid

# %%
# Verificando se os dados estão no hdfs

# !hdfs dfs -ls /user/wesley/covid
# Out:
# Found 4 items
# -rw-r--r--   3 root supergroup   62492959 2022-08-06 01:32 /user/wesley/covid/HIST_PAINEL_COVIDBR_2020_Parte1_06jul2021.csv
# -rw-r--r--   3 root supergroup   76520681 2022-08-06 01:39 /user/wesley/covid/HIST_PAINEL_COVIDBR_2020_Parte2_06jul2021.csv
# -rw-r--r--   3 root supergroup   91120916 2022-08-06 01:39 /user/wesley/covid/HIST_PAINEL_COVIDBR_2021_Parte1_06jul2021.csv
# -rw-r--r--   3 root supergroup    3046774 2022-08-06 01:40 /user/wesley/covid/HIST_PAINEL_COVIDBR_2021_Parte2_06jul2021.csv

# %% [markdown]
# ## 2. Otimizar todos os dados do hdfs para uma tabela Hive particionada por município

# %%
# Verificando o conteúdo do arquivo

# !hdfs dfs -tail /user/wesley/covid/HIST_PAINEL_COVIDBR_2020_Parte1_06jul2021.csv
# Out:
# 30010;53001;DISTRITO FEDERAL;2020-07-22;30;3015268;87801;1725;1176;18;;;1
# Centro-Oeste;DF;Brasília;53;530010;53001;DISTRITO FEDERAL;2020-07-23;30;3015268;90023;2222;1218;42;;;1
# Centro-Oeste;DF;Brasília;53;530010;53001;DISTRITO FEDERAL;2020-07-24;30;3015268;92414;2391;1244;26;;;1
# Centro-Oeste;DF;Brasília;53;530010;53001;DISTRITO FEDERAL;2020-07-25;30;3015268;94187;1773;1275;31;;;1
# Centro-Oeste;DF;Brasília;53;530010;53001;DISTRITO FEDERAL;2020-07-26;31;3015268;96332;2145;1308;33;;;1
# Centro-Oeste;DF;Brasília;53;530010;53001;DISTRITO FEDERAL;2020-07-27;31;3015268;98480;2148;1339;31;;;1
# Centro-Oeste;DF;Brasília;53;530010;53001;DISTRITO FEDERAL;2020-07-28;31;3015268;100726;2246;1391;52;;;1
# Centro-Oeste;DF;Brasília;53;530010;53001;DISTRITO FEDERAL;2020-07-29;31;3015268;102342;1616;1419;28;;;1
# Centro-Oeste;DF;Brasília;53;530010;53001;DISTRITO FEDERAL;2020-07-30;31;3015268;104442;2100;1444;25;;;1
# Centro-Oeste;DF;Brasília;53;530010;53001;DISTRITO FEDERAL;2020-07-31;31;3015268;106292;1850;1469;25;;;1

# %%
# Lendo os arquivos para um dataframe

df = spark.read.csv("/user/wesley/covid/*.csv", sep=';', header=True, inferSchema = True)
df.show(5)
# Out:
# +------+------+---------+-----+------+--------------+---------------+-------------------+---------+----------------+--------------+----------+---------------+-----------+----------------+---------------------+----------------------+
# |regiao|estado|municipio|coduf|codmun|codRegiaoSaude|nomeRegiaoSaude|               data|semanaEpi|populacaoTCU2019|casosAcumulado|casosNovos|obitosAcumulado|obitosNovos|Recuperadosnovos|emAcompanhamentoNovos|interior/metropolitana|
# +------+------+---------+-----+------+--------------+---------------+-------------------+---------+----------------+--------------+----------+---------------+-----------+----------------+---------------------+----------------------+
# |Brasil|  null|     null|   76|  null|          null|           null|2020-02-25 00:00:00|        9|       210147125|             0|         0|              0|          0|            null|                 null|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-02-26 00:00:00|        9|       210147125|             1|         1|              0|          0|            null|                 null|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-02-27 00:00:00|        9|       210147125|             1|         0|              0|          0|            null|                 null|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-02-28 00:00:00|        9|       210147125|             1|         0|              0|          0|            null|                 null|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-02-29 00:00:00|        9|       210147125|             2|         1|              0|          0|            null|                 null|                  null|
# +------+------+---------+-----+------+--------------+---------------+-------------------+---------+----------------+--------------+----------+---------------+-----------+----------------+---------------------+----------------------+
# only showing top 5 rows

# %%
# Verificando o schema da tabela

df.printSchema()
# Out:
# root
#  |-- regiao: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- municipio: string (nullable = true)
#  |-- coduf: integer (nullable = true)
#  |-- codmun: integer (nullable = true)
#  |-- codRegiaoSaude: integer (nullable = true)
#  |-- nomeRegiaoSaude: string (nullable = true)
#  |-- data: timestamp (nullable = true)
#  |-- semanaEpi: integer (nullable = true)
#  |-- populacaoTCU2019: integer (nullable = true)
#  |-- casosAcumulado: decimal(10,0) (nullable = true)
#  |-- casosNovos: integer (nullable = true)
#  |-- obitosAcumulado: integer (nullable = true)
#  |-- obitosNovos: integer (nullable = true)
#  |-- Recuperadosnovos: integer (nullable = true)
#  |-- emAcompanhamentoNovos: integer (nullable = true)
#  |-- interior/metropolitana: integer (nullable = true)

# %%
# pegando apenas algumas colunas para entender o dataframe, com isto verifiquei que possui diversos valores nulos

df.select("regiao", "estado", "municipio", 'Recuperadosnovos', 'emAcompanhamentoNovos', "data").show(10)
# Out:
# +------+------+---------+----------------+---------------------+-------------------+
# |regiao|estado|municipio|Recuperadosnovos|emAcompanhamentoNovos|               data|
# +------+------+---------+----------------+---------------------+-------------------+
# |Brasil|  null|     null|            null|                 null|2020-02-25 00:00:00|
# |Brasil|  null|     null|            null|                 null|2020-02-26 00:00:00|
# |Brasil|  null|     null|            null|                 null|2020-02-27 00:00:00|
# |Brasil|  null|     null|            null|                 null|2020-02-28 00:00:00|
# |Brasil|  null|     null|            null|                 null|2020-02-29 00:00:00|
# |Brasil|  null|     null|            null|                 null|2020-03-01 00:00:00|
# |Brasil|  null|     null|            null|                 null|2020-03-02 00:00:00|
# |Brasil|  null|     null|            null|                 null|2020-03-03 00:00:00|
# |Brasil|  null|     null|            null|                 null|2020-03-04 00:00:00|
# |Brasil|  null|     null|            null|                 null|2020-03-05 00:00:00|
# +------+------+---------+----------------+---------------------+-------------------+
# only showing top 10 rows

# %%
# Alterando o padrão de data para o formato brasileiro

df = df.withColumn('data', f.from_unixtime(f.unix_timestamp(df.data), "yyyy-MM-dd"))

# %%
# Verificando se foi alterado a data

df.select("regiao", "estado", "municipio", 'Recuperadosnovos', 'emAcompanhamentoNovos', "data").show(10)
# Out:
# +------+------+---------+----------------+---------------------+----------+
# |regiao|estado|municipio|Recuperadosnovos|emAcompanhamentoNovos|      data|
# +------+------+---------+----------------+---------------------+----------+
# |Brasil|  null|     null|            null|                 null|2020-02-25|
# |Brasil|  null|     null|            null|                 null|2020-02-26|
# |Brasil|  null|     null|            null|                 null|2020-02-27|
# |Brasil|  null|     null|            null|                 null|2020-02-28|
# |Brasil|  null|     null|            null|                 null|2020-02-29|
# |Brasil|  null|     null|            null|                 null|2020-03-01|
# |Brasil|  null|     null|            null|                 null|2020-03-02|
# |Brasil|  null|     null|            null|                 null|2020-03-03|
# |Brasil|  null|     null|            null|                 null|2020-03-04|
# |Brasil|  null|     null|            null|                 null|2020-03-05|
# +------+------+---------+----------------+---------------------+----------+
# only showing top 10 rows

# %% [markdown]
# ### Criando o banco no Hive:
# - Para salvar os dados em uma tabela Hive, primeiro precisamos  acessar o Hive e criar um database
# - Acessando o Hive: docker exec -it hive-server bash
# - Acessando o Beeline: beeline -u jdbc:hive2://Localhost:10000
# - create database projeto_semantix comment "banco de dados do para o projeto final do curso data enginner da semantix"

# %%
# Salvando os dados em tabela hive particionado pelo municipio

df.write.mode("overwrite").partitionBy('municipio').saveAsTable('projeto_semantix.wesley')

# %%
# Confirmando o particionamento por municipio

# !hdfs dfs -ls /user/hive/warehouse/projeto_semantix.db/wesley
# Out:
# Found 5298 items
# -rw-r--r--   2 root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/_SUCCESS
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Abadia de Goiás
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Abadia dos Dourados
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Abadiânia
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Abaetetuba
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Abaeté
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Abaiara
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Abaré
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Abatiá
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Abaíra
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Abdon Batista
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Abel Figueiredo
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Abelardo Luz
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Abre Campo
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Abreu e Lima
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Abreulândia
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Acaiaca
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Acajutiba
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Acarape
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Acaraú
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Acari
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Acará
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Acauã
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Aceguá
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Acopiara
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Acorizal
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Acrelândia
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Acreúna
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Adamantina
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Adelândia
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Adolfo
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Adrianópolis
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Adustina
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Afogados da Ingazeira
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Afonso Bezerra
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Afonso Cláudio
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Afonso Cunha
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Afrânio
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Afuá
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Agrestina
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Agricolândia
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Agrolândia
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Agronômica
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Aguanil
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Aguaí
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Agudo
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Agudos
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Agudos do Sul
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Aguiar
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Aguiarnópolis
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Aimorés
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Aiquara
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Aiuaba
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Aiuruoca
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Ajuricaba
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alagoa
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alagoa Grande
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alagoa Nova
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alagoinha
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alagoinha do Piauí
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alagoinhas
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alambari
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Albertina
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alcantil
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alcinópolis
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alcobaça
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alcântara
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alcântaras
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Aldeias Altas
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alecrim
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alegre
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alegrete
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alegrete do Piauí
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alegria
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alenquer
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alexandria
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alexânia
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alfenas
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alfredo Chaves
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alfredo Marcondes
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alfredo Vasconcelos
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alfredo Wagner
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Algodão de Jandaíra
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alhandra
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Aliança
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Aliança do Tocantins
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Almadina
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Almas
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Almeirim
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Almenara
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Almino Afonso
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Almirante Tamandaré
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Almirante Tamandaré do Sul
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Aloândia
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alpercata
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alpestre
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alpinópolis
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alta Floresta
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alta Floresta D%27Oeste
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Altair
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Altamira
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Altamira do Maranhão
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Altamira do Paraná
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Altaneira
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alterosa
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Altinho
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Altinópolis
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alto Alegre
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Alto Alegre do Maranhão
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Westfália
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Witmarsum
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Xambioá
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Xambrê
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Xangri-lá
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Xanxerê
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Xapuri
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Xavantina
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Xaxim
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Xexéu
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Xinguara
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Xique-Xique
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Zabelê
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Zacarias
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Zortéa
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Zé Doca
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Água Azul do Norte
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Água Boa
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Água Branca
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Água Clara
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Água Comprida
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Água Doce
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Água Doce do Maranhão
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Água Doce do Norte
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Água Fria
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Água Fria de Goiás
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Água Limpa
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Água Nova
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Água Preta
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Água Santa
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Águas Belas
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Águas Formosas
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Águas Frias
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Águas Lindas de Goiás
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Águas Mornas
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Águas Vermelhas
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Águas da Prata
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Águas de Chapecó
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Águas de Lindóia
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Águas de Santa Bárbara
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Águas de São Pedro
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Águia Branca
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Álvares Florence
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Álvares Machado
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Álvaro de Carvalho
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Áurea
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Ângulo
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Érico Cardoso
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Óbidos
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:15 /user/hive/warehouse/projeto_semantix.db/wesley/municipio=Óleo

# %% [markdown]
# ## 3.  Criar 3 vizualizações pelo Spark com os dados enviados para o HDFS:

# %%
# A primeira visualzização é o total de recuperados e o total em Acompanhamentos
# Utilizando a última data que possui essas informações atualizadas

visual1 = df.select("Recuperadosnovos", "emAcompanhamentoNovos").where(df.data == '2021-07-06')
visual1.show(1)
# Out:
# +----------------+---------------------+
# |Recuperadosnovos|emAcompanhamentoNovos|
# +----------------+---------------------+
# |        17262646|              1065477|
# +----------------+---------------------+
# only showing top 1 row

# %%
# A segunda visualização é o total de casos confirmados Acumulado, Casos Novos e Incidência

df1 = df.where(df.data == "2021-07-06")
visual2 = df1.select("casosAcumulado", 
                     "casosNovos", 
                     f.round(df1['casosAcumulado']/df1['populacaoTCU2019']*100000,1)
                     .alias("incidência"))
visual2.show(1)
# Out:
# +--------------+----------+----------+
# |casosAcumulado|casosNovos|incidência|
# +--------------+----------+----------+
# |      18855015|     62504|    8972.3|
# +--------------+----------+----------+
# only showing top 1 row

# %%
# A terceira visualização é óbitos acumulados, casos novos, letalidade e mortalidade
# A letalidade seria o valor de obitos acumulado dividido pelo número de casos acumulado

visual3 = df1.select("obitosAcumulado", 
                     "obitosNovos",
                     f.round(df1['obitosAcumulado']/df1['casosAcumulado']*100,1)
                     .alias("Letalidade"),
                     f.round(df1['obitosAcumulado']/df1['populacaoTCU2019']*100000,1)
                     .alias("Mortalidade"))
visual3.show(1)
# Out:
# +---------------+-----------+----------+-----------+
# |obitosAcumulado|obitosNovos|Letalidade|Mortalidade|
# +---------------+-----------+----------+-----------+
# |         526892|       1780|       2.8|      250.7|
# +---------------+-----------+----------+-----------+
# only showing top 1 row

# %% [markdown]
# ## 4. Salvar a primeira visualização como tabela Hive

# %%
visual1.write.mode("overwrite").saveAsTable("projeto_semantix.visual1")

# %%
# Verificando se foi salvo no Hive

# !hdfs dfs -ls /user/hive/warehouse/projeto_semantix.db
# Out:
# Found 3 items
# drwxr-xr-x   - root supergroup          0 2022-08-06 02:55 /user/hive/warehouse/projeto_semantix.db/covid
# drwxr-xr-x   - root supergroup          0 2022-08-06 19:42 /user/hive/warehouse/projeto_semantix.db/visual1
# drwxr-xr-x   - root supergroup          0 2022-08-06 03:17 /user/hive/warehouse/projeto_semantix.db/wesley

# %% [markdown]
# ## 5. Salvar a segunda visualização com formato parquet e compressão snappy

# %%
visual2.write.parquet("/user/wesley/visual2", compression='snappy')

# %%
# Verificando se foi salvo

# !hdfs dfs -ls /user/wesley/visual2
# Out:
# Found 3 items
# -rw-r--r--   2 root supergroup          0 2022-08-06 19:48 /user/wesley/visual2/_SUCCESS
# -rw-r--r--   2 root supergroup        496 2022-08-06 19:48 /user/wesley/visual2/part-00000-f2cf59e9-9535-4e93-9534-041b80c4a120-c000.snappy.parquet
# -rw-r--r--   2 root supergroup      56169 2022-08-06 19:48 /user/wesley/visual2/part-00003-f2cf59e9-9535-4e93-9534-041b80c4a120-c000.snappy.parquet

# %% [markdown]
# ## 6. Salvar a terceira visualização em um tópico no Kafka

# %%
visual3.selectExpr("to_json(struct(*)) AS value")\
    .write\
    .format('kafka')\
    .option('kafka.bootstrap.servers', 'kafka:9092')\
    .option('topic', 'obitos_brasil')\
    .save()

# %% [markdown]
# +-------------------------------------------------------------------------------------------------------+
# |value                                                                                                  |
# +-------------------------------------------------------------------------------------------------------+
# |{"Região":"Brasil","Óbitos_Acumulados":526892,"Óbitos_Novos":1780,"Letalidade":2.8,"Mortalidade":250.7}|
# |{"Região":"Brasil","Óbitos_Acumulados":526892,"Óbitos_Novos":1780,"Letalidade":2.8,"Mortalidade":250.7}|
# +-------------------------------------------------------------------------------------------------------+

# %%
# Lendo o arquivo que foi salvo no tópico do kafka

obitos = spark.read.format('kafka').option('kafka.bootstrap.servers', 'kafka:9092').option('subscribe', 'visual3').load()

# %% [markdown]
# ## 7. Criar a visualização pelo Spark com os dados enviados para o HDFS:

# %%
# Visual 4 mostra o total de Casos, Óbitos, Incidência/100mil hab, Mortalidade/100mil hab

visual4 = df1.groupBy('regiao')\
            .agg(sum('casosAcumulado')\
            .alias("casos"),sum('obitosAcumulado')\
            .alias('Óbitos'),max('populacaoTCU2019')\
            .alias("Populacao"))

visual4 = (visual4.withColumn('Incidência/100mil hab.', f.round(visual4['casos']/visual4['Populacao']*100000,1))
          .withColumn('Mortalidade/100mil hab.', f.round(visual4['Óbitos']/visual4['Populacao']*100000,1)))

visual4 = visual4.drop('Populacao')

visual4.sort(col('regiao').asc()).show()
# Out:
# +------------+--------+------+----------------------+-----------------------+
# |      regiao|   casos|Óbitos|Incidência/100mil hab.|Mortalidade/100mil hab.|
# +------------+--------+------+----------------------+-----------------------+
# |      Brasil|18855015|526892|                8972.3|                  250.7|
# |Centro-Oeste| 3833238| 98414|               54617.3|                 1402.2|
# |    Nordeste| 8911474|215648|               59916.9|                 1449.9|
# |       Norte| 3465630| 87690|               40284.6|                 1019.3|
# |     Sudeste|14277606|490622|               31093.0|                 1068.4|
# |         Sul| 7222082|161410|               63163.5|                 1411.7|
# +------------+--------+------+----------------------+-----------------------+
